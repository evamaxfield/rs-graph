# %%
from rs_graph.data import load_matched_dev_author_ids_dataset

matched_dev_authors = load_matched_dev_author_ids_dataset()
matched_dev_authors
# Out:
#          gh_username   author_id  match_proba             name  h_index  \
# 0     oliver-sanders    40395514     0.999990   Oliver Sanders      2.0
# 1           debanjum  2117397383     0.999981         Debanjum      1.0
# 2     wielandbrendel    40634590     0.999967  Wieland Brendel     31.0
# 3     zoran-cuckovic    51877471     0.999967   Zoran Čučković      3.0
# 4              huard  2014219529     0.999966      David Huard      2.0
# ...              ...         ...          ...              ...      ...
# 3202      kberryUSGS  2055381283     0.504310         K. Berry      5.0
# 3203       ben-whale    74609006     0.502903         B. Whale      8.0
# 3204    alekseyzimin     2812174     0.502481         A. Zimin     40.0
# 3205    eggplantbren    34308753     0.502109        B. Brewer     31.0
# 3206        tiagoseq    38003835     0.501102      T. Sequeira     18.0
#
#                                           contributions
# ...

# %%
matched_dev_authors.sort_values(by=["h_index"], ascending=False)
# Out:
#            gh_username   author_id  match_proba              name  h_index  \
# 377           salzberg     1744109     0.998604       S. Salzberg    148.0
# 2542         aronwalsh   144485183     0.860757          A. Walsh    101.0
# 3146  jolien-creighton     3286468     0.548785      J. Creighton     91.0
# 1547              farr     3305699     0.977567           W. Farr     88.0
# 298              zonca   103231899     0.999016          A. Zonca     87.0
# ...                ...         ...          ...               ...      ...
# 811     simoninireland   145445938     0.994996      Simon Dobson      0.0
# 1800       Thomasjkeel  2218071854     0.964048          Tom Keel      0.0
# 392           henrikdv  2238628746     0.998502  Henrik Dvergsdal      0.0
# 345     beniaminogreen  2248137892     0.998779   Beniamino Green      0.0
# 1499          muellsen  2150086656     0.979834  Christian Müller      NaN
#
#                                           contributions
# ...
