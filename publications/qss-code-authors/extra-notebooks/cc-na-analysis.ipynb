# %%
from pathlib import Path

import pandas as pd
from sklearn.metrics import cohen_kappa_score

EXTRA_DATA_DIR = Path.cwd().parent / "extra-data"

initial_set = pd.read_csv(EXTRA_DATA_DIR / "cc-na-initial-resolved-set.csv")
initial_unresolved_set = pd.read_csv(
    EXTRA_DATA_DIR / "cc-na-initial-unresolved-set.csv"
)
eva_set = pd.read_csv(EXTRA_DATA_DIR / "cc-na-eva.csv")
nic_set = pd.read_csv(EXTRA_DATA_DIR / "cc-na-nic.csv")
nic_set["is_bot_account"] = "no"
nic_set = nic_set.drop(
    columns=[col for col in nic_set.columns if col.startswith("Unnamed:")]
)

# Combine the datasets
combined_set = pd.concat(
    [initial_set, eva_set, nic_set], ignore_index=True
).reset_index(drop=True)
combined_set
# Out:
#      document_id                                       document_doi  \
# 0         107848     https://doi.org/10.1088/1748-0221/18/11/P11028
# 1          44180       https://doi.org/10.1371/journal.pone.0263125
# 2          33751                   https://doi.org/10.29012/jpc.870
# 3          56650          https://doi.org/10.1007/s41095-021-0229-5
# 4          21394         https://doi.org/10.1109/TPAMI.2017.2769085
# ..           ...                                                ...
# 195        41129         https://doi.org/10.1038/s41598-021-87709-7
# 196        61912            https://doi.org/10.1145/3511808.3557275
# 197        53557        https://doi.org/10.1109/ACCESS.2021.3112879
# 198       155656               https://doi.org/10.1613/jair.1.13326
# 199       136972  https://doi.org/10.1109/ICASSP49357.2023.10096189
#
#      repository_id                                     repository_url  \
# 0           104357               https://github.com/dnicotra/trackhhl
# 1            42221  https://github.com/lukemelas/efficientnet-pytorch
# 2            32267        https://github.com/microsoft/prv_accountant
# 3            54205                  https://github.com/menghaoguo/pct
# 4            20529       https://github.com/hbilen/dynamic-image-nets
# ..             ...                                                ...
# 195          39281   https://github.com/gcampede/terrorism-metagraphs
# 196          59280         https://github.com/intellabs/nlp-architect
# 197          51256       https://github.com/gtlidar/tamp-manipulation
# 198         151946                 https://github.com/kebaek/minigrid
# 199         133157              https://github.com/splend1d/t5lephone
#
#      developer_account_id                 developer_account_url  \
# 0                  131471            https://github.com/dmark04
# 1                   71221         https://github.com/robotrapta
# 2                   36697          https://github.com/s-zanella
# 3                    2123         https://github.com/Menghao999
# 4                   42202             https://github.com/Blssel
# ..                    ...                                   ...
# 195                 67511           https://github.com/gcampede
# 196                 90822  https://github.com/chinnikrishna2231
# 197                 81979           https://github.com/edrumwri
# 198                166678             https://github.com/YX-S-Z
# 199                 73942           https://github.com/Splend1d
#
#                             developer_contribution_url  n_commits  \
# 0    https://github.com/dnicotra/trackhhl/commits?a...        0.0
# 1    https://github.com/lukemelas/efficientnet-pyto...        1.0
# 2    https://github.com/microsoft/prv_accountant/co...        1.0
# 3    https://github.com/menghaoguo/pct/commits?auth...        1.0
# 4    https://github.com/hbilen/dynamic-image-nets/c...        1.0
# ..                                                 ...        ...
# 195  https://github.com/gcampede/terrorism-metagrap...       17.0
# 196  https://github.com/intellabs/nlp-architect/com...        4.0
# 197  https://github.com/gtlidar/tamp-manipulation/c...      176.0
# 198  https://github.com/kebaek/minigrid/commits?aut...        6.0
# 199  https://github.com/splend1d/t5lephone/commits?...       17.0
#
#      n_additions  n_deletions  total_repo_commits  total_repo_additions  \
# 0            0.0          0.0                11.0                 924.0
# 1            1.0          1.0               120.0                8902.0
# 2            1.0          1.0                35.0                3604.0
# 3           11.0          1.0                30.0                1201.0
# 4            2.0          2.0              1403.0              163258.0
# ..           ...          ...                 ...                   ...
# 195      30595.0         29.0                17.0               30595.0
# 196       1479.0        125.0               451.0              601777.0
# 197          0.0          0.0             25004.0                   0.0
# 198         40.0         13.0                41.0               10517.0
# 199     108653.0      88215.0                19.0              108747.0
#
#      total_repo_deletions contrib_type is_actually_author is_bot_account  \
# 0                   712.0        other                 no             no
# 1                  3609.0          doc            unclear             no
# 2                   883.0         code                 no             no
# 3                    65.0         code                yes             no
# 4                 86480.0        other                 no             no
# ..                    ...          ...                ...            ...
# 195                  29.0         code                yes             no
# 196              111623.0         code                 no             no
# 197                   0.0         code                 no             no
# 198                1970.0         code                yes             no
# 199               88216.0         code                yes             no
#
#                        notes
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 195  First author repo owner
# 196                      NaN
# 197              Alt branch
# 198             First author
# 199               Repo owner
#
# [200 rows x 17 columns]

# %%
# Get kappa score for initial unresolved set for:
# "eva-contrib-type" vs "nic-contrib-type"
# "eva-is_actually_author" vs "nic-is_actually_author"
# "eva-bot_account" vs "nic-bot_account"

for comparison in [
    ("eva-contrib-type", "nic-contrib-type"),
    ("eva-is_actually_author", "nic-is_actually_author"),
    ("eva-bot_account", "nic-bot_account"),
]:
    col1, col2 = comparison
    kappa = cohen_kappa_score(
        initial_unresolved_set[col1], initial_unresolved_set[col2]
    )
    print(f"Cohen's Kappa for {col1} vs {col2}: {kappa:.4f}")
# Out:
# Cohen's Kappa for eva-contrib-type vs nic-contrib-type: 0.8851
# Cohen's Kappa for eva-is_actually_author vs nic-is_actually_author: 1.0000
# Cohen's Kappa for eva-bot_account vs nic-bot_account: nan
# /Users/evamaxfield/.local/share/mamba/envs/rs-graph/lib/python3.12/site-packages/sklearn/metrics/_classification.py:534: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# /Users/evamaxfield/.local/share/mamba/envs/rs-graph/lib/python3.12/site-packages/sklearn/metrics/_classification.py:897: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)

# %%
# Get subset of rows in which is_actually_author is "no"
not_author_set = combined_set[combined_set["is_actually_author"] == "yes"]
for _, row in not_author_set.iterrows():
    print("Document DOI:", row["document_doi"])
    print("Developer Account:", row["developer_account_url"])
    print()
# Out:
# Document DOI: https://doi.org/10.1007/s41095-021-0229-5
# Developer Account: https://github.com/Menghao999
#
# Document DOI: https://doi.org/10.1145/3477495.3531715
# Developer Account: https://github.com/raojay7
#
# Document DOI: https://doi.org/10.1088/1361-6544/ac0d46
# Developer Account: https://github.com/KaleonXie
#
# Document DOI: https://doi.org/10.1016/j.patcog.2024.110729
# Developer Account: https://github.com/xingy038
#
# Document DOI: https://doi.org/10.1016/j.patrec.2023.02.018
# Developer Account: https://github.com/kmbmjn
#
# Document DOI: https://doi.org/10.1371/journal.pcbi.1005931
# Developer Account: https://github.com/krzbar
#
# Document DOI: https://doi.org/10.1109/ICCV51070.2023.01884
# Developer Account: https://github.com/stevenlsw
#
# Document DOI: https://doi.org/10.1145/3613904.3642065
# Developer Account: https://github.com/xybruceliu
#
# Document DOI: https://doi.org/10.1109/CVPR.2019.01078
# Developer Account: https://github.com/kang205
#
# Document DOI: https://doi.org/10.3847/1538-3881/ab2390
# Developer Account: https://github.com/h21k
#
# Document DOI: https://doi.org/10.1016/j.icarus.2023.115845
# Developer Account: https://github.com/AlbinoCarbo
#
# Document DOI: https://doi.org/10.1109/IROS47612.2022.9981732
# Developer Account: https://github.com/quimortiz
#
# Document DOI: https://doi.org/10.1145/3543507.3583398
# Developer Account: https://github.com/anjaliakg17
#
# Document DOI: https://doi.org/10.1109/CVPR52688.2022.01131
# Developer Account: https://github.com/huiserwang
#
# Document DOI: https://doi.org/10.48550/arXiv.2407.08563
# Developer Account: https://github.com/leahvdh
#
# Document DOI: https://doi.org/10.1109/TVCG.2020.2988476
# Developer Account: https://github.com/jby1993
#
# Document DOI: https://doi.org/10.1109/ICCV48922.2021.00126
# Developer Account: https://github.com/AGI-init
#
# Document DOI: https://doi.org/10.1109/jstsp.2024.3387299
# Developer Account: https://github.com/salmane-s9
#
# Document DOI: https://doi.org/10.1186/s12859-022-04688-w
# Developer Account: https://github.com/usmaann
#
# Document DOI: https://doi.org/10.1109/TMM.2023.3314153
# Developer Account: https://github.com/luogen1996
#
# Document DOI: https://doi.org/10.1109/CVPRW59228.2023.00544
# Developer Account: https://github.com/nchappa
#
# Document DOI: https://doi.org/10.1609/aaai.v35i18.17931
# Developer Account: https://github.com/pietruh
#
# Document DOI: https://doi.org/10.1109/ICCV51070.2023.00358
# Developer Account: https://github.com/zhongcl-thu
#
# Document DOI: https://doi.org/10.1109/CVPR52688.2022.01368
# Developer Account: https://github.com/mengqiDyangge
#
# Document DOI: https://doi.org/10.3389/fmed.2021.746307
# Developer Account: https://github.com/khtao
#
# Document DOI: https://doi.org/10.1609/aaai.v38i9.28850
# Developer Account: https://github.com/JakobHeiss
#
# Document DOI: https://doi.org/10.1109/TPAMI.2019.2963387
# Developer Account: https://github.com/oibook13
#
# Document DOI: https://doi.org/10.1371/journal.pone.0236371
# Developer Account: https://github.com/sjmuellerbt
#
# Document DOI: https://doi.org/10.1145/3405794
# Developer Account: https://github.com/khoapham
#
# Document DOI: https://doi.org/10.1109/CVPR52729.2023.00495
# Developer Account: https://github.com/kebijuelun
#
# Document DOI: https://doi.org/10.1109/ICRA48891.2023.10160855
# Developer Account: https://github.com/georgeliu233
#
# Document DOI: https://doi.org/10.1109/TCSVT.2019.2935128
# Developer Account: https://github.com/jackryo
#
# Document DOI: https://doi.org/10.48550/arXiv.2403.01924
# Developer Account: https://github.com/disi-unibo-nlp
#
# Document DOI: https://doi.org/10.1109/CVPR52729.2023.00768
# Developer Account: https://github.com/bobma-bytedance
#
# Document DOI: https://doi.org/10.1016/j.cose.2022.103051
# Developer Account: https://github.com/efchatz
#
# Document DOI: https://doi.org/10.1109/ICCV48922.2021.00931
# Developer Account: https://github.com/mj33rice
#
# Document DOI: https://doi.org/10.1371/journal.pdig.0000108
# Developer Account: https://github.com/cctrotte
#
# Document DOI: https://doi.org/10.1103/PhysRevE.103.063308
# Developer Account: https://github.com/misiekc
#
# Document DOI: https://doi.org/10.1093/comnet/cnac051
# Developer Account: https://github.com/roysgitprojects
#
# Document DOI: https://doi.org/10.1109/JAS.2020.1003390
# Developer Account: https://github.com/SuSir1996
#
# Document DOI: https://doi.org/10.1109/IC2E52221.2021.00018
# Developer Account: https://github.com/j95io
#
# Document DOI: https://doi.org/10.1145/3578337.3605143
# Developer Account: https://github.com/dayuyang1999
#
# Document DOI: https://doi.org/10.1007/s11263-024-02142-3
# Developer Account: https://github.com/jasongief
#
# Document DOI: https://doi.org/10.48550/arxiv.2111.00243
# Developer Account: https://github.com/govindjsk
#
# Document DOI: https://doi.org/10.1103/PhysRevD.107.036004
# Developer Account: https://github.com/jsalvado
#
# Document DOI: https://doi.org/10.1007/978-3-030-45190-5_25
# Developer Account: https://github.com/Leslieaj
#
# Document DOI: https://doi.org/10.1145/3459637.3482177
# Developer Account: https://github.com/tedzhouhk
#
# Document DOI: https://doi.org/10.1109/CVPR52729.2023.01510
# Developer Account: https://github.com/sndnyang
#
# Document DOI: https://doi.org/10.1007/s00521-021-06282-2
# Developer Account: https://github.com/DavidMrd
#
# Document DOI: https://doi.org/10.1371/journal.pcbi.1011476
# Developer Account: https://github.com/liqingbioinfo
#
# Document DOI: https://doi.org/10.1109/CVPR52733.2024.00840
# Developer Account: https://github.com/hse1032
#
# Document DOI: https://doi.org/10.1609/aaai.v36i10.21409
# Developer Account: https://github.com/xssstory
#
# Document DOI: https://doi.org/10.1109/CVPRW50498.2020.00427
# Developer Account: https://github.com/hchoi71
#
# Document DOI: https://doi.org/10.1103/PhysRevD.109.055024
# Developer Account: https://github.com/skalia618
#
# Document DOI: https://doi.org/10.1371/journal.pcbi.1010078
# Developer Account: https://github.com/yunPKU
#
# Document DOI: https://doi.org/10.1103/PhysRevA.104.062432
# Developer Account: https://github.com/kgeorgopoulos2
#
# Document DOI: https://doi.org/10.48550/arXiv.2406.04148
# Developer Account: https://github.com/maijuka
#
# Document DOI: https://doi.org/10.1145/3411764.3445315
# Developer Account: https://github.com/Foroughp
#
# Document DOI: https://doi.org/10.1038/s41598-021-87709-7
# Developer Account: https://github.com/gcampede
#
# Document DOI: https://doi.org/10.1613/jair.1.13326
# Developer Account: https://github.com/YX-S-Z
#
# Document DOI: https://doi.org/10.1109/ICASSP49357.2023.10096189
# Developer Account: https://github.com/Splend1d

# %% [markdown]
# ### Notes on Missed Authors
#
# First off, this is specifically "code-contributing non-authors," or, "code-contributors that we didn't match to any author." Given that our model is decently _conservative_ in it's predictions, we would expect there to be some author misses here (i.e. it prefers no-match to match). And to us, this is a good thing, we want to be decently sure of a match and we don't want to misattribute a lot of individuals, even at the cost of 33% or potentially more misses.
#
# 1. We do much better with "Anglosaxon" names
# 2. Even if there is some information that shows likely author (to us as annotators), if there are longer words or phrases in the name that are unrelated, the model seems likely to tend towards no-match
# 3. When the username and provided name are decently different. I.e. not the case of a shortened name (i.e. from Robert to Bob or William to Will) but for potentially a chosen English name -- This is acutally likely the biggest source of misses
# 4. We dug way harder into accounts than the model is shown information, for example, some of our annotations / classifications were only possible because we looked at the GitHub accounts linked website. From text alone, we would likely label the pair as "no-match" or "unsure"

# %%
# Get the count and pct of bot accounts
bot_count = combined_set["is_bot_account"].value_counts()
bot_pct = combined_set["is_bot_account"].value_counts(normalize=True) * 100
bot_count, bot_pct
# Out:
# (is_bot_account
#  no     198
#  yes      2
#  Name: count, dtype: int64,
#  is_bot_account
#  no     99.0
#  yes     1.0
#  Name: proportion, dtype: float64)

# %%
# Get the count and pct of actual authors we missed (is_actually_author)
author_cls_counts = combined_set["is_actually_author"].value_counts()
author_cls_pct = combined_set["is_actually_author"].value_counts(normalize=True) * 100
author_cls_counts, author_cls_pct
# Out:
# (is_actually_author
#  no         78
#  unclear    61
#  yes        61
#  Name: count, dtype: int64,
#  is_actually_author
#  no         39.0
#  unclear    30.5
#  yes        30.5
#  Name: proportion, dtype: float64)

# %%
# Drop bot accounts
# Then groupby author cls and get the count of contribution type (contrib_type)
combined_set.loc[combined_set["is_bot_account"] == "no"].groupby("is_actually_author")[
    "contrib_type"
].value_counts().unstack().fillna(0).astype(int)
# Out:
# contrib_type        code  doc  other
# is_actually_author
# no                    59   13      4
# unclear               50    8      3
# yes                   49   12      0

# %%
# Same thing but with pct
combined_set.loc[combined_set["is_bot_account"] == "no"].groupby("is_actually_author")[
    "contrib_type"
].value_counts(normalize=True).unstack().fillna(0) * 100
# Out:
# contrib_type             code        doc     other
# is_actually_author
# no                  77.631579  17.105263  5.263158
# unclear             81.967213  13.114754  4.918033
# yes                 80.327869  19.672131  0.000000

# %%
def _get_stats_for_author_cls(
    data: pd.DataFrame, author_cls: str | list[str], repo_owner_filter: str = "all"
) -> pd.DataFrame:
    # Get repo owner from repository_url
    data["repo_owner"] = data["repository_url"].str.split("/").str[3].str.lower()
    # Get contributor name from developer_account_url
    data["contributor_name"] = (
        data["developer_account_url"].str.split("/").str[3].str.lower()
    )

    # Handle ignore_repo_owners
    if repo_owner_filter == "none":
        # Filter out rows where repo_owner == contributor_name
        data = data.loc[data["repo_owner"] != data["contributor_name"]].copy()
    elif repo_owner_filter == "only":
        # Filter to only rows where repo_owner == contributor_name
        data = data.loc[data["repo_owner"] == data["contributor_name"]].copy()
    # If repo_owner_filter is "all", do nothing

    # Filter to author cls
    if isinstance(author_cls, str):
        # If author_cls is a string, filter to that single class
        data = data.loc[data["is_actually_author"] == author_cls].copy()
    elif isinstance(author_cls, list):
        # If author_cls is a list, filter to those classes
        data = data.loc[data["is_actually_author"].isin(author_cls)].copy()

    # Scope down to just is_actually_author == author_cls
    # And which contribution type is "code"
    # Take the quantiles, mean, and std of their commits (n_commits)
    # divided by total commits (total_repo_commits)
    commit_stats = (
        data.loc[(data["is_bot_account"] == "no") & (data["contrib_type"] == "code")]
        .dropna(subset=["n_commits", "total_repo_commits"])
        .apply(lambda x: x["n_commits"] / x["total_repo_commits"], axis=1)
        .describe()
        .round(3)
    )

    # Same thing but for n_additions and total_repo_additions
    addition_stats = (
        data.loc[
            (data["is_bot_account"] == "no")
            & (data["contrib_type"] == "code")
            & (data["total_repo_additions"] > 0)
        ]
        .dropna(subset=["n_additions", "total_repo_additions"])
        .apply(lambda x: x["n_additions"] / x["total_repo_additions"], axis=1)
        .describe()
        .round(3)
    )

    # Same thing but with n_deletions and total_repo_deletions
    deletion_stats = (
        data.loc[
            (data["is_bot_account"] == "no")
            & (data["contrib_type"] == "code")
            & (data["total_repo_deletions"] > 0)
        ]
        .dropna(subset=["n_deletions", "total_repo_deletions"])
        .apply(lambda x: x["n_deletions"] / x["total_repo_deletions"], axis=1)
        .describe()
        .round(3)
    )

    # Combine n_additions and n_deletions into a single column
    # Combined total additions and deletions into a single column
    data["n_additions_deletions"] = data["n_additions"].fillna(0) + data[
        "n_deletions"
    ].fillna(0)
    data["total_repo_additions_deletions"] = data["total_repo_additions"].fillna(
        0
    ) + data["total_repo_deletions"].fillna(0)
    # Calculate the ratio of additions and deletions to total repo additions and deletions
    abs_stats = (
        data.loc[
            (data["is_bot_account"] == "no")
            & (data["contrib_type"] == "code")
            & (data["total_repo_additions_deletions"] > 0)
        ]
        .dropna(subset=["n_additions_deletions", "total_repo_additions_deletions"])
        .apply(
            lambda x: x["n_additions_deletions"] / x["total_repo_additions_deletions"],
            axis=1,
        )
        .describe()
        .round(3)
    )

    # Create frame
    stats_frame = pd.DataFrame(
        {
            "commit_stats": commit_stats,
            "addition_stats": addition_stats,
            "deletion_stats": deletion_stats,
            "abs_stats": abs_stats,
        }
    ).T

    return stats_frame


_get_stats_for_author_cls(combined_set, "no")
# Out:
#                 count   mean    std    min    25%    50%    75%  max
# commit_stats     53.0  0.178  0.307  0.001  0.007  0.029  0.107  1.0
# addition_stats   51.0  0.227  0.380  0.000  0.001  0.007  0.192  1.0
# deletion_stats   51.0  0.193  0.358  0.000  0.000  0.006  0.149  1.0
# abs_stats        51.0  0.222  0.379  0.000  0.001  0.010  0.144  1.0

# %%
_get_stats_for_author_cls(combined_set, "unclear")
# Out:
#                 count   mean    std    min    25%  50%  75%  max
# commit_stats     50.0  0.747  0.366  0.004  0.505  1.0  1.0  1.0
# addition_stats   50.0  0.722  0.420  0.000  0.310  1.0  1.0  1.0
# deletion_stats   45.0  0.737  0.417  0.000  0.722  1.0  1.0  1.0
# abs_stats        50.0  0.733  0.404  0.000  0.417  1.0  1.0  1.0

# %%
# My take away here is that we at least have 25% of the 30% making sizable contributions
# Reasoning being, 75th percentile is 25% making ~10% of total commits and abs additions/deletions
# Is that _worthy_ of authorship? Who knows, but 10% of total commits/additions/deletions is decent
# That is still ~7.5% of all papers

# Given that 25th percentile of unclear authors is also pretty high but not 100%,
# its likely that _some_ of those are also true "not authors"
0.25 * 30
# Out:
# 7.5

# %%
# If we ignore repo owners, we can see the stats are a bit more distributed
# And I would argue that its maybe somewhere between 25% and 50% of unclear, non-repo owner authors
_get_stats_for_author_cls(combined_set, "no", repo_owner_filter="only")
# Out:
#                 count   mean    std    min    25%    50%  75%  max
# commit_stats      4.0  0.804  0.275  0.417  0.704  0.900  1.0  1.0
# addition_stats    4.0  0.956  0.084  0.830  0.953  0.997  1.0  1.0
# deletion_stats    4.0  0.915  0.141  0.706  0.891  0.976  1.0  1.0
# abs_stats         4.0  0.953  0.087  0.822  0.948  0.995  1.0  1.0

# %%
# If we ignore repo owners, we can see the stats are a bit more distributed
# And I would argue that its maybe somewhere between 25% and 50% of unclear, non-repo owner authors
_get_stats_for_author_cls(combined_set, "unclear", repo_owner_filter="none")
# Out:
#                 count   mean    std    min    25%    50%    75%  max
# commit_stats     20.0  0.454  0.399  0.004  0.041  0.346  0.841  1.0
# addition_stats   20.0  0.380  0.443  0.000  0.016  0.094  0.917  1.0
# deletion_stats   20.0  0.486  0.492  0.000  0.003  0.431  0.999  1.0
# abs_stats        20.0  0.392  0.440  0.000  0.011  0.127  0.919  1.0

# %%
# If we ignore repo owners, we can see the stats are a bit more distributed
# And I would argue that its maybe somewhere between 25% and 50% of unclear, non-repo owner authors
_get_stats_for_author_cls(combined_set, "unclear", repo_owner_filter="only")
# Out:
#                 count   mean    std    min  25%  50%  75%  max
# commit_stats     30.0  0.943  0.152  0.444  1.0  1.0  1.0  1.0
# addition_stats   30.0  0.949  0.187  0.016  1.0  1.0  1.0  1.0
# deletion_stats   25.0  0.938  0.180  0.158  1.0  1.0  1.0  1.0
# abs_stats        30.0  0.961  0.124  0.407  1.0  1.0  1.0  1.0

# %%
# I think an estimate of 10% of all papers have a code-contributing non-author is reasonable
# Down from 30% to 10%, to me that is still a lot. Esp considering we are mostly dealing with
# analysis code. There are likely papers which rely on RSE developed tools which exist in separate repos
# and are not captured here.

# %%
_get_stats_for_author_cls(combined_set, ["unclear", "no"])
# Out:
#                 count   mean    std    min    25%    50%  75%  max
# commit_stats    103.0  0.455  0.440  0.001  0.019  0.317  1.0  1.0
# addition_stats  101.0  0.472  0.469  0.000  0.004  0.243  1.0  1.0
# deletion_stats   96.0  0.448  0.472  0.000  0.002  0.149  1.0  1.0
# abs_stats       101.0  0.475  0.467  0.000  0.004  0.338  1.0  1.0

# %%
_get_stats_for_author_cls(combined_set, ["unclear", "no"], repo_owner_filter="none")
# Out:
#                 count   mean    std    min    25%    50%    75%  max
# commit_stats     69.0  0.222  0.332  0.001  0.008  0.048  0.317  1.0
# addition_stats   67.0  0.229  0.375  0.000  0.001  0.013  0.272  1.0
# deletion_stats   67.0  0.237  0.398  0.000  0.000  0.006  0.174  1.0
# abs_stats        67.0  0.229  0.375  0.000  0.001  0.013  0.259  1.0

# %%
_get_stats_for_author_cls(combined_set, ["unclear", "no"], repo_owner_filter="only")
# Out:
#                 count   mean    std    min  25%  50%  75%  max
# commit_stats     34.0  0.926  0.171  0.417  1.0  1.0  1.0  1.0
# addition_stats   34.0  0.950  0.177  0.016  1.0  1.0  1.0  1.0
# deletion_stats   29.0  0.935  0.174  0.158  1.0  1.0  1.0  1.0
# abs_stats        34.0  0.960  0.119  0.407  1.0  1.0  1.0  1.0

# %%
_get_stats_for_author_cls(combined_set, "no", repo_owner_filter="only")
# Out:
#                 count   mean    std    min    25%    50%  75%  max
# commit_stats      4.0  0.804  0.275  0.417  0.704  0.900  1.0  1.0
# addition_stats    4.0  0.956  0.084  0.830  0.953  0.997  1.0  1.0
# deletion_stats    4.0  0.915  0.141  0.706  0.891  0.976  1.0  1.0
# abs_stats         4.0  0.953  0.087  0.822  0.948  0.995  1.0  1.0
