# %%
import polars as pl
from sci_soft_models.dev_author_em import (
    DeveloperDetails,
    load_dev_author_em_model,
    match_devs_and_authors,
)
from sklearn.metrics import classification_report, cohen_kappa_score
from tqdm import tqdm

annotations = pl.read_csv("../extra-data/author-developer-annotated-pairs-resolved.csv")

# Drop unnamed columns if they exist
annotations = annotations.drop("")

annotations
# Out:
# shape: (535, 18)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ dataset_s ┆ document_ ┆ document_ ┆ document_ ┆ … ┆ nic_label ┆ eva_notes ┆ nic_notes ┆ final_la │
# │ ource_nam ┆ repositor ┆ id        ┆ url       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ bel      │
# │ e         ┆ y_link_id ┆ ---       ┆ ---       ┆   ┆ str       ┆ str       ┆ str       ┆ ---      │
# │ ---       ┆ ---       ┆ i64       ┆ str       ┆   ┆           ┆           ┆           ┆ str      │
# │ str       ┆ i64       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ plos      ┆ 8545      ┆ 8530      ┆ https://d ┆ … ┆ match     ┆ null      ┆ null      ┆ match    │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆           ┆           ┆          │
# │ plos      ┆ 8545      ┆ 8530      ┆ https://d ┆ … ┆ no-match  ┆ null      ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆           ┆           ┆          │
# │ plos      ┆ 8545      ┆ 8530      ┆ https://d ┆ … ┆ no-match  ┆ null      ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆           ┆           ┆          │
# │ plos      ┆ 8545      ┆ 8530      ┆ https://d ┆ … ┆ no-match  ┆ null      ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆           ┆           ┆          │
# │ plos      ┆ 8545      ┆ 8530      ┆ https://d ┆ … ┆ no-match  ┆ null      ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ softwarex ┆ 163221    ┆ 157240    ┆ https://d ┆ … ┆ no-match  ┆ null      ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1016/j.s ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ oft…      ┆   ┆           ┆           ┆           ┆          │
# │ softwarex ┆ 163227    ┆ 157246    ┆ https://d ┆ … ┆ no-match  ┆ null      ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1016/J.S ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ OFT…      ┆   ┆           ┆           ┆           ┆          │
# │ softwarex ┆ 163227    ┆ 157246    ┆ https://d ┆ … ┆ match     ┆ null      ┆ null      ┆ match    │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1016/J.S ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ OFT…      ┆   ┆           ┆           ┆           ┆          │
# │ softwarex ┆ 163269    ┆ 157288    ┆ https://d ┆ … ┆ match     ┆ null      ┆ null      ┆ match    │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1016/J.S ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ OFT…      ┆   ┆           ┆           ┆           ┆          │
# │ softwarex ┆ 163269    ┆ 157288    ┆ https://d ┆ … ┆ no-match  ┆ null      ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1016/J.S ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ OFT…      ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Show rows where eva_label is not equal to nic_label
annotations.filter(pl.col("eva_label") != pl.col("nic_label"))
# Out:
# shape: (6, 18)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ dataset_s ┆ document_ ┆ document_ ┆ document_ ┆ … ┆ nic_label ┆ eva_notes ┆ nic_notes ┆ final_la │
# │ ource_nam ┆ repositor ┆ id        ┆ url       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ bel      │
# │ e         ┆ y_link_id ┆ ---       ┆ ---       ┆   ┆ str       ┆ str       ┆ str       ┆ ---      │
# │ ---       ┆ ---       ┆ i64       ┆ str       ┆   ┆           ┆           ┆           ┆ str      │
# │ str       ┆ i64       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ plos      ┆ 9379      ┆ 9364      ┆ https://d ┆ … ┆ no-match  ┆ from text ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆ informati ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆ on alone, ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆ n…        ┆           ┆          │
# │ plos      ┆ 9906      ┆ 9891      ┆ https://d ┆ … ┆ no-match  ┆ likely    ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆ the       ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆ correct   ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆ match but ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ d…        ┆           ┆          │
# │ plos      ┆ 9906      ┆ 9891      ┆ https://d ┆ … ┆ no-match  ┆ likely    ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆ the       ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆ correct   ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆ account   ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ but…      ┆           ┆          │
# │ plos      ┆ 44324     ┆ 43895     ┆ https://d ┆ … ┆ match     ┆ out of    ┆ null      ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆ all of    ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆ them this ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆ one mi…   ┆           ┆          │
# │ pwc       ┆ 155536    ┆ 150095    ┆ https://d ┆ … ┆ unsure    ┆ null      ┆ burner    ┆ match    │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .48550/ar ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ xiv…      ┆   ┆           ┆           ┆           ┆          │
# │ pwc       ┆ 155536    ┆ 150095    ┆ https://d ┆ … ┆ match     ┆ null      ┆ null      ┆ match    │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .48550/ar ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ xiv…      ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Get cohen kappa score of eva_label and nic_label
cohen_kappa_score(
    annotations["eva_label"],
    annotations["nic_label"],
)
# Out:
# 0.9481262423037766

# %%
# Load the author developer EM model
dev_author_em_model = load_dev_author_em_model()

# Create predictions for each doc repo pair
predicted_rows = []
for _, group in tqdm(
    annotations.drop(["eva_notes", "nic_notes"]).group_by(
        "document_repository_link_id"
    ),
    total=annotations["document_repository_link_id"].n_unique(),
):
    # Iter rows in group
    for row in group.iter_rows(named=True):
        developer_details = DeveloperDetails(
            username=row["developer_username"],
            name=row["developer_name"],
            email=row["developer_email"],
        )
        this_row_predictions = match_devs_and_authors(
            devs=[developer_details],
            authors=[row["author_name"]],
            loaded_dev_author_em_model=dev_author_em_model,
        )
        predicted_rows.append(
            {
                **row,
                "predicted_label": (
                    "match" if len(this_row_predictions) > 0 else "no-match"
                ),
            }
        )

# Convert predicted_rows to a polars dataframe
predicted_df = pl.DataFrame(predicted_rows)

# Drop rows where final label is null
predicted_df = predicted_df.filter(pl.col("final_label").is_not_null())

# Show rows where final_label is not equal to predicted_label
predicted_df.filter(pl.col("final_label") != pl.col("predicted_label"))
# Out:
# Device set to use mps
# 100%|██████████| 56/56 [00:21<00:00,  2.64it/s]
# shape: (13, 17)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ dataset_s ┆ document_ ┆ document_ ┆ document_ ┆ … ┆ eva_label ┆ nic_label ┆ final_lab ┆ predicte │
# │ ource_nam ┆ repositor ┆ id        ┆ url       ┆   ┆ ---       ┆ ---       ┆ el        ┆ d_label  │
# │ e         ┆ y_link_id ┆ ---       ┆ ---       ┆   ┆ str       ┆ str       ┆ ---       ┆ ---      │
# │ ---       ┆ ---       ┆ i64       ┆ str       ┆   ┆           ┆           ┆ str       ┆ str      │
# │ str       ┆ i64       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ pwc       ┆ 155536    ┆ 150095    ┆ https://d ┆ … ┆ no-match  ┆ match     ┆ match     ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .48550/ar ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ xiv…      ┆   ┆           ┆           ┆           ┆          │
# │ pwc       ┆ 38788     ┆ 38439     ┆ https://d ┆ … ┆ match     ┆ match     ┆ match     ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .18653/v1 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ /20…      ┆   ┆           ┆           ┆           ┆          │
# │ softwarex ┆ 163227    ┆ 157246    ┆ https://d ┆ … ┆ match     ┆ match     ┆ match     ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1016/J.S ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ OFT…      ┆   ┆           ┆           ┆           ┆          │
# │ softwarex ┆ 162960    ┆ 156984    ┆ https://d ┆ … ┆ no-match  ┆ no-match  ┆ no-match  ┆ match    │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1016/j.s ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ oft…      ┆   ┆           ┆           ┆           ┆          │
# │ plos      ┆ 9906      ┆ 9891      ┆ https://d ┆ … ┆ unsure    ┆ no-match  ┆ no-match  ┆ match    │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ plos      ┆ 9379      ┆ 9364      ┆ https://d ┆ … ┆ no-match  ┆ no-match  ┆ no-match  ┆ match    │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆           ┆           ┆          │
# │ plos      ┆ 9379      ┆ 9364      ┆ https://d ┆ … ┆ unsure    ┆ no-match  ┆ no-match  ┆ match    │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1371/jou ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ rna…      ┆   ┆           ┆           ┆           ┆          │
# │ softwarex ┆ 162951    ┆ 156975    ┆ https://d ┆ … ┆ match     ┆ match     ┆ match     ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1016/j.s ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ oft…      ┆   ┆           ┆           ┆           ┆          │
# │ softwarex ┆ 163141    ┆ 157160    ┆ https://d ┆ … ┆ match     ┆ match     ┆ match     ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .1016/j.s ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ oft…      ┆   ┆           ┆           ┆           ┆          │
# │ pwc       ┆ 60657     ┆ 59871     ┆ https://d ┆ … ┆ match     ┆ match     ┆ match     ┆ no-match │
# │           ┆           ┆           ┆ oi.org/10 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .48550/ar ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ xiv…      ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# Print basic details of each row
for row in predicted_df.filter(
    pl.col("final_label") != pl.col("predicted_label")
).iter_rows(named=True):
    print("Author:", row["author_name"])
    print(
        "Developer:",
        row["developer_username"],
        row["developer_name"],
        row["developer_email"],
    )
    print("Final label:", row["final_label"])
    print("Predicted label:", row["predicted_label"])
    print()
# Out:
# Author: M.P. SAHU
# Developer: Mohit-coder-droid None None
# Final label: match
# Predicted label: no-match
#
# Author: Kemal Kurniawan
# Developer: kemal1056949 None None
# Final label: match
# Predicted label: no-match
#
# Author: Mihiran Galagedarage Don
# Developer: mihiranpathmika None None
# Final label: match
# Predicted label: no-match
#
# Author: Ángel López-Gázquez
# Developer: Julopvel Julián López Velásquez None
# Final label: no-match
# Predicted label: match
#
# Author: Scott E. Evans
# Developer: EvansLaboratory None None
# Final label: no-match
# Predicted label: match
#
# Author: Nickolay Safonov
# Developer: nickossaf None None
# Final label: match
# Predicted label: no-match
#
# Author: Chloe Brimicombe
# Developer: chlobrim Chloe None
# Final label: match
# Predicted label: no-match
#
# Author: Katie Major-Smith
# Developer: djsmith-90 None None
# Final label: no-match
# Predicted label: match
#
# Author: Juyeon Kim
# Developer: jkimlab None None
# Final label: no-match
# Predicted label: match
#
# Author: Jaebum Kim
# Developer: jkimlab None None
# Final label: no-match
# Predicted label: match
#
# Author: Max Spencer
# Developer: maxspe-dtu None None
# Final label: match
# Predicted label: no-match
#
# Author: Nikolaos Karathanasopoulos
# Developer: nkarathan None None
# Final label: match
# Predicted label: no-match
#
# Author: Pål Vegard Johnsen
# Developer: palVJ None None
# Final label: match
# Predicted label: no-match

# %%
# Get the classification report for final_label and predicted_label
print(
    classification_report(
        predicted_df["final_label"],
        predicted_df["predicted_label"],
    ),
)
# Out:
#               precision    recall  f1-score   support
#
#        match       0.92      0.87      0.89        63
#     no-match       0.98      0.99      0.99       472
#
#     accuracy                           0.98       535
#    macro avg       0.95      0.93      0.94       535
# weighted avg       0.98      0.98      0.98       535

# %%
# Iter over dataset_source_name and get classification report for each
for dataset_source_name, group in predicted_df.group_by("dataset_source_name"):
    print(f"Classification report for {dataset_source_name}")
    print(
        classification_report(
            group["final_label"],
            group["predicted_label"],
        ),
    )
    print()
# Out:
# Classification report for ('pwc',)
#               precision    recall  f1-score   support
#
#        match       1.00      0.81      0.89        21
#     no-match       0.96      1.00      0.98        97
#
#     accuracy                           0.97       118
#    macro avg       0.98      0.90      0.94       118
# weighted avg       0.97      0.97      0.96       118
#
#
# Classification report for ('plos',)
#               precision    recall  f1-score   support
#
#        match       0.79      1.00      0.88        15
#     no-match       1.00      0.98      0.99       188
#
#     accuracy                           0.98       203
#    macro avg       0.89      0.99      0.94       203
# weighted avg       0.98      0.98      0.98       203
#
#
# Classification report for ('softwarex',)
#               precision    recall  f1-score   support
#
#        match       0.96      0.85      0.90        27
#     no-match       0.98      0.99      0.99       187
#
#     accuracy                           0.98       214
#    macro avg       0.97      0.92      0.94       214
# weighted avg       0.98      0.98      0.98       214
